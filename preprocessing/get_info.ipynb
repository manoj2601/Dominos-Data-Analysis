# %%
import pandas as pd
import numpy as np
import os
import json
import re
from os.path import join
from pathlib import Path

# %%
path = "/media/root/data/analysis/data/Order_wise_data/"
p2 = "/media/root/data/analysis/data/Item_wise_data/"
citys = ['Bhopal/', 'Delhi/', 'Jaipur/', 'Kolkata/', 'Mumbai/']
months = ['Dec.csv', 'July.csv']

# %%
l = citys
l2 = months

# %%
for x in l:
    for y in l2:
        print(x,y)
        df = pd.read_csv(path+x+y)
        print(len(df))
        print(df.Store_id.nunique())
        print()
# dfd = df.groupby(['rider_id','store_id']).size().reset_index(name='count')
# print(len(dfd))
# Out:
# Bhopal/ Dec.csv
# 19881
# 10
#
# Bhopal/ July.csv
# 44566
# 11
#
# Delhi/ Dec.csv
# 480612
# 184
#
# Delhi/ July.csv
# 402299
# 204
#
# Jaipur/ Dec.csv
# 31446
# 15
#
# Jaipur/ July.csv
# 63602
# 17
#
# Kolkata/ Dec.csv
# 88849
# 50
#
# Kolkata/ July.csv
# 201325
# 54
#
# Mumbai/ Dec.csv
# 236030
# 87
#
# Mumbai/ July.csv
# 446767
# 87

# %%
df
# Out:
#         Store_id City_name  Order_date  Order_number  \
# 0       DPI67132     Delhi  2021-12-17           250
# 1       DPI66718     Delhi  2021-12-17           307
# 2       DPI66257     Delhi  2021-12-17           306
# 3       DPI66325     Delhi  2021-12-17           225
# 4       DPI66106     Delhi  2021-12-17           309
# ...          ...       ...         ...           ...
# 480607  DPI66718     Delhi  2021-12-30           232
# 480608  DPI65834     Delhi  2021-12-30           193
# 480609  DPI65957     Delhi  2021-12-30           196
# 480610  DPI66158     Delhi  2021-12-30           213
# 480611  DPI66369     Delhi  2021-12-30           225
#
#                                               Order_Items  Store_lat  \
# 0       [{"quantity": 1, "menu_code": "TACNV06", "volu...  28.589777
# 1       [{"quantity": 1, "menu_code": "PIZ0125", "volu...  28.631446
# 2       [{"quantity": 1, "menu_code": "BEV0123", "volu...  28.501110
# ...
